# %%
from histogram import Histogram
from pystat_funcs import get_descriptives
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('calories.csv')
data.shape
# Out:
# (15000, 9)

# %%
data.head(3)
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0

# %%
get_descriptives(data.iloc[:, 1:], table_color='lightblue')
# Out:
# <style type="text/css">
# #T_74667 thead {
#   background-color: lightblue;
# }
# #T_74667 tbody tr:nth-child(even) {
#   background-color: lightblue;
# }
# #T_74667 tbody tr:nth-child(odd) {
#   background-color: white;
# }
# </style>
# <table id="T_74667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74667_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_74667_level0_col1" class="col_heading level0 col1" >Mean</th>
#       <th id="T_74667_level0_col2" class="col_heading level0 col2" >SD</th>
#       <th id="T_74667_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_74667_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_74667_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_74667_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_74667_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
histogram = Histogram(data)

# %%
histogram.set_col('Heart_Rate')

# %%
histogram.plot()

# %%
histogram.set_col('Age')

# %%
histogram.plot(fpath='histograms/age.png')

# %%
histogram.set_col('Weight')

# %%
histogram.set_group('Gender')

# %%
histogram.plot(x_pos=100, y_pos=520, plot_title='Weight By Gender', fpath='histograms/weight-by-gender.png')
